# %%
revenue=10
expense=40

# %%
try:
    profit =revenue-expense
    margin=profit*100/revenue
    print(f"The margin is {margin:.2f}%")
except ZeroDivisionError:
       print("you got zero division error so you can't divide zero with number try again with valid revenue")
# Out:
# The margin is -300.00%
